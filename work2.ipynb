# %% [markdown]
# <a href="https://colab.research.google.com/github/RKRO-uns/Prog2kakushin/blob/main/work2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#案：今日見れる星座の列挙、星座を当てる
import numpy as np
import matplotlib.pyplot as plt

#print("星座の名前を当てろ！！")
#print("全部で5問あるよ")
#print("-------------------")
#print("第１問")
#画像の表示
#a=input("")


#オリオン座
posi= np.array([[-10,-20,-25,-16,-10,0,-8,30,16,23,11,-10,11,23,50,58,59,57.5,55],[150,130,128,113,108,75,45,48,80,103,118,108,118,103,130,114,105,100,93]])
posi1=np.array([[8],[77.5]])
##冬の大三角形
posi2=np.array([[-10,-99.5,-45,-10],[108,103,9,108]])
#こいぬ座
posi3=np.array([[-99.5,-88],[103,115]])
#おおいぬ座
posi4=np.array([[-45,],[9,]])





plt.plot(posi[0, :], posi[1, :])
plt.plot(posi2[0, :], posi2[1, :])
plt.plot(posi3[0, :], posi3[1, :])

plt.plot(posi[0,:], posi[1,:], '.', color='red')
plt.plot(posi1[0,:], posi1[1,:], '.', color='red')
plt.plot(posi3[0,:], posi3[1,:], '.', color='red')
plt.plot(posi2[0,:], posi2[1,:], '.', color='green')



#plt.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False, bottom=False, left=False, right=False, top=False)
plt.axis('equal')
plt.show()
